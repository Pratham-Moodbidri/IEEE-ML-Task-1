# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratham-Moodbidri/IEEE-ML-Task-1/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
path = "/content/drive/MyDrive/tvmarketing.csv"
df = pd.read_csv(path)
print(df)
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df.TV, df.Sales, 'r.')
plt.show()

# %%
lr = LinearRegression()

# %%
X = df['TV'].values.reshape(-1, 1)
y = df['Sales'].values.reshape(-1, 1)
lr.fit(X, y)
print("Intercept:", lr.intercept_)
print("Coefficient:", lr.coef_)
new_X = [[200]]
prediction = lr.predict(new_X)
print("Prediction of sales of 200 TV :", prediction[0][0])
# Out:
# Intercept: [7.03259355]
# Coefficient: [[0.04753664]]
# Prediction of sales of 200 TV : 16.539921635731645

# %%
y_pred = lr.predict(X)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
print("Mean squared error:", mse)
print("Root mean squared error:", rmse)
# Out:
# Mean squared error: 10.512652915656757
# Root mean squared error: 3.2423221486546887

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.title("Linear Regression Model")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.show()
